# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_name="C:\\Users\\Durga prasan sarangi\\jupyter\\naresh it\\data science omkar sir\\Visadataset.csv"
visadataset=pd.read_csv(file_name)

# %%
visadatasetfile_name="C:\\Users\\Durga prasan sarangi\\jupyter\\naresh it\\data science omkar sir\\ Visadataset.csv"
visadataset=pd.read_csv(file_name)
visadataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visadataset['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visadataset['prevailing_wage'].mean()       # by using pandas
# Out:
# 74455.81459209183

# %%
round(visadataset['prevailing_wage'].mean(),2)
# Out:
# 74455.81

# %%
np.mean(visadataset['prevailing_wage'])        # by using numpy
# Out:
# 74455.81459209183

# %%
visadataset['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
np.median(visadataset['prevailing_wage'])
# Out:
# 70308.20999999999

# %%
max(visadataset['prevailing_wage'])
# Out:
# 319210.27

# %%
min(visadataset['prevailing_wage'])
# Out:
# 2.1367

# %%
visadataset['prevailing_wage'].std()
# Out:
# 52815.94232687357

# %%
visadataset['prevailing_wage'].count()
# Out:
# 25480

# %%
p_mean=round(visadataset['prevailing_wage'].mean(),2)
p_medi=round(visadataset['prevailing_wage'].median(),2)
p_std=round(visadataset['prevailing_wage'].std(),2)
p_max=round(visadataset['prevailing_wage'].max(),2)
p_min=round(visadataset['prevailing_wage'].min(),2)
p_count=round(visadataset['prevailing_wage'].count(),2)
dict1={'mean':p_mean,
      'median':p_medi,
      'std':p_std,
      'max':p_max,
      'min':p_min,
      'count':p_count}
dict1
pd.DataFrame(dict1,index=['prevailing_wage'])
# Out:
#                      mean    median       std        max   min  count
# prevailing_wage  74455.81  70308.21  52815.94  319210.27  2.14  25480

# %%
list1=[p_mean,p_medi,p_std,p_max,p_min,p_count]
pd.DataFrame(list1,columns=['prevailing_wage'],index=['mean','median','std','max','min','count'])
# Out:
#         prevailing_wage
# mean           74455.81
# median         70308.21
# std            52815.94
# max           319210.27
# min                2.14
# count          25480.00

# %%
visadataset.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Durga prasan sarangi\\jupyter\\naresh it\\data science omkar sir'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_name='Visadataset.csv'
visadataset=pd.read_csv(file_name)
visadataset.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# $Numerical analysis$

# %%
visadataset['prevailing_wage'].unique()
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
visadataset['prevailing_wage'].nunique()
# Out:
# 25454

# %% [markdown]
# **percentile**and**quantiles**

# %%
data=visadataset['prevailing_wage']
round(np.percentile(data,25),2)
# Out:
# 34015.48

# %%
data=visadataset['prevailing_wage']
per_25=np.percentile(data,25)
round(per_25,2)
# Out:
# 34015.48

# %%
len(visadataset[visadataset['prevailing_wage']<34015])
# Out:
# 6370

# %%
6370/25480
# Out:
# 0.25

# %%
data=visadataset['prevailing_wage']
np.percentile(data,[25,50,75])
# Out:
# array([ 34015.48  ,  70308.21  , 107735.5125])

# %%
data=visadataset['prevailing_wage']
per_25=round(np.percentile(data,25),2)
per_50=round(np.percentile(data,50),2)
per_75=round(np.percentile(data,75),2)
per_20=round(np.percentile(data,20),2)
print(per_25,per_50,per_75,per_20)
# Out:
# 34015.48 70308.21 107735.51 25674.21

# %%
np.quantile(data,0.25)         # same as per_25 for quantile use decimal
# Out:
# 34015.479999999996

# %%
np.quantile(data,0.5)
# Out:
# 70308.20999999999

# %%
data=visadataset['prevailing_wage']
quant_25=round(np.quantile(data,0.25),2)
quant_50=round(np.quantile(data,0.50),2)
quant_75=round(np.quantile(data,0.75),2)
quant_20=round(np.quantile(data,0.20),2)
print(quant_25,quant_50,quant_75,quant_20)
# Out:
# 34015.48 70308.21 107735.51 25674.21

# %%
dict2={}
dict2['p_mean']=round(visadataset['prevailing_wage'].mean(),2)
dict2['p_medi']=round(visadataset['prevailing_wage'].median(),2)
dict2['p_std']=round(visadataset['prevailing_wage'].std(),2)
dict2['p_max']=round(visadataset['prevailing_wage'].max(),2)
dict2['p_min']=round(visadataset['prevailing_wage'].min(),2)
dict2['p_count']=round(visadataset['prevailing_wage'].count(),2)
dict2['25%']=round(np.percentile(data,25),2)
dict2['50%']=round(np.percentile(data,50),2)
dict2['75%']=round(np.percentile(data,75),2)

pd.DataFrame(dict1,index=['prevailing_wage'])
# Out:
#                      mean    median       std        max   min  count
# prevailing_wage  74455.81  70308.21  52815.94  319210.27  2.14  25480

# %%
dict2.keys()
# Out:
# dict_keys(['p_mean', 'p_medi', 'p_std', 'p_max', 'p_min', 'p_count', '25%', '50%', '75%'])

# %%
dict2.values()
# Out:
# dict_values([74455.81, 70308.21, 52815.94, 319210.27, 2.14, 25480, 34015.48, 70308.21, 107735.51])

# %%
pd.DataFrame(dict2.values(),columns=['prevaling_wage'],index=dict2.keys())
# Out:
#          prevaling_wage
# p_mean         74455.81
# p_medi         70308.21
# p_std          52815.94
# p_max         319210.27
# p_min              2.14
# p_count        25480.00
# 25%            34015.48
# 50%            70308.21
# 75%           107735.51

# %% [markdown]
# $plots$

# %% [markdown]
# **Histogram**

# %%
data=visadataset['prevailing_wage']
plt.hist(data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
data=visadataset['prevailing_wage']
plt.hist(data,bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
# ...

# %%
data=visadataset['prevailing_wage']
frequency,interval,n=plt.hist(data,bins=40)

# %%
frequency
# Out:
# array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#        1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#         509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#          79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#           7.,    3.,    6.,    5.])

# %%
interval
# Out:
# array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#        3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#        6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#        9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#        1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#        1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#        1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#        2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#        2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#        2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#        3.19210270e+05])

# %%
n
# Out:
# <BarContainer object of 40 artists>

# %%
data=visadataset['prevailing_wage']
plt.hist(data,bins=40)
plt.show()

# %%
7.98234003e+03
# Out:
# 7982.34003

# %%
2.13670000e+00
# Out:
# 2.1367

# %%
1.59625434e+04
# Out:
# 15962.5434

# %%
len(visadataset[(visadataset['prevailing_wage']>7982.34003)&(visadataset['prevailing_wage']<15962.5434)])
# Out:
# 871

# %%
data=visadataset['prevailing_wage']
plt.hist(data,bins=40,color='r')
plt.show()

# %%
plt.hist2d(data,data)
plt.show()

# %%
sns.histplot(data)
plt.show()

# %%
data=visadataset['prevailing_wage']
plt.hist(data,bins=40,color='r')
plt.xlabel('intervals')
plt.ylabel('count')
plt.title('histogram')
plt.savefig('wages_histogram.png')
plt.show()

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x161b8361030>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x161b8362170>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x161b8362770>],
#  'medians': [<matplotlib.lines.Line2D at 0x161b82c9450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x161b82ca560>],
#  'means': []}

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data,vert=False)
plt.show()

# %%
Q1=round(np.quantile(data,0.25),2)
Q2=round(np.quantile(data,0.50),2)
Q3=round(np.quantile(data,0.75),2)
IQR=(Q3-Q1)
LB=Q1-1.5*IQR
UB=Q3+1.5*IQR

print('Q1:',Q1)
print('Q2:',Q2)
print('Q3:',Q3)
print('IQR:',IQR)
print('LB:',LB)
print('UB:',UB)
# Out:
# Q1: 34015.48
# Q2: 70308.21
# Q3: 107735.51
# IQR: 73720.03
# LB: -76564.565
# UB: 218315.555

# %%
data=visadataset['prevailing_wage']
con1=data<LB
con2=data>UB
con1|con2
outliers_data=visadataset[con1|con2]
#visadataset[(data>7982.34003)&
            #(data<15962.5434)]

# %%
len(outliers_data)
# Out:
# 427

# %%
outliers_data
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
outliers_data['prevailing_wage']
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
outliers=outliers_data['prevailing_wage'].to_list()

# %%
len(outliers)
# Out:
# 427

# %%
[i for i in outliers if i<LB]
# Out:
# []

# %%
outliers
# Out:
# [220081.73,
#  225569.73,
#  247393.01,
#  269321.68,
#  219529.62,
#  232227.33,
#  238691.32,
#  220448.17,
#  230750.48,
#  235339.91,
#  232680.65,
#  256261.78,
#  262189.0,
#  250510.67,
#  218554.78,
#  256205.38,
#  221944.22,
#  229950.7,
#  222628.84,
#  229819.69,
#  233641.72,
#  274019.43,
#  218982.83,
#  230984.28,
#  223128.23,
#  246705.0,
#  240266.34,
#  226090.72,
#  231949.27,
#  254604.08,
#  288318.91,
#  244457.48,
#  242146.48,
#  247545.23,
#  234139.17,
#  231834.72,
#  222730.57,
#  239773.63,
#  220553.95,
#  237539.32,
#  266440.49,
#  277281.01,
#  275627.59,
#  249291.12,
#  292106.59,
#  234012.11,
#  247009.24,
#  267726.09,
#  222098.09,
#  280661.13,
#  277984.52,
#  262852.71,
#  263877.21,
#  230916.64,
#  264760.64,
#  267868.56,
#  222221.67,
#  242406.32,
#  276894.08,
#  281832.93,
#  221033.57,
#  258292.84,
#  223492.85,
#  245418.67,
#  250289.08,
#  271344.69,
#  252825.11,
#  230843.7,
#  253668.86,
#  245819.17,
#  239465.3,
# ...

# %%
 Q1-1.5IQR            Q1   median  Q3       Q3+1.5IQR
                       |-----:-----|
       o      |--------|     :     |--------|    o  o
                       |-----:-----|
     flier             <----------->            fliers
                            IQR
# Out:
#   File <tokenize>:3
#     o      |--------|     :     |--------|    o  o
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
sns.distplot(visadataset['prevailing_wage'])
# Out:
# C:\Users\Durga prasan sarangi\AppData\Local\Temp\ipykernel_14840\3636735311.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(visadataset['prevailing_wage'])
# <Axes: xlabel='prevailing_wage', ylabel='Density'>

# %%
sns.pairplot(outliers_data)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

visadataset.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'no_of_employees'}>,
#         <Axes: title={'center': 'yr_of_estab'}>],
#        [<Axes: title={'center': 'prevailing_wage'}>, <Axes: >]],
#       dtype=object)

# %%
sns.pairplot(visadataset)
